# %% [markdown]
# # Workshop 3. Doing research with hydrological data

# %% [markdown]
# ## Index
# - [Topic 1. Soil moisture index](#topic-1-soil-moisture-index)
# - [Topic 2. Uncertainty in the rainfall record](#topic-2-rainfall-uncertainty)
# - [Topic 3. Determining flood & droughts](#topic-3-determining-floods-and-droughts)
#
# Students will be given 3 potential topics
# - Soil Moisture
# - Rainfall data (gauge vs grid)
# - Floods/Droughts (NRFA data and rainfall)
#
# They will be given some code but will need to use materials from the other sessions and find support from the helpers.

# %%
# Load required libraries

# %% [markdown]
# ## Topic 1. Soil moisture index
# [Back to Index](#index)
#
# #### Contents
# - Calculate soil moisture index between soils
#
# **Data sources:**
# - soil moisture and related soil variables - COSMOS API

# %% [markdown]
# ### 1.1 load in data from COSMOS API
# For simplicity, we have moved the functions required for extracting data from the COSMOS API to the file `get_cosmos_data.py`. These functions were covered in **Section X.X** of Workshop 1.

# %%
import datetime
import get_cosmos_data

# %%
s_df = get_cosmos_data.get_single_station_data(
    station_name='BUNNY',
    start_date=datetime.datetime(2016, 1, 1),
    end_date=datetime.datetime(2022, 12, 31),
    variable_list=['tdt1_tsoil', 'tdt1_vwc', 'ta']
    )
# Out:
# https://cosmos-api.ceh.ac.uk/collections/1D/locations
# https://cosmos-api.ceh.ac.uk/collections/1D/locations/BUNNY?datetime=2016-01-01T00:00:00Z/2022-12-31T00:00:00Z&parameter-name=stp_tsoil1,tdt1_vwc,ta
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s_df = get_cosmos_data.get_single_station_data(
#       2     station_name='BUNNY',
#       3     start_date=datetime.datetime(2016, 1, 1),
#       4     end_date=datetime.datetime(2022, 12, 31),
#       5     variable_list=['stp_tsoil1', 'tdt1_vwc', 'ta']
#       6     )
#
# File ~/Dev/Workshops/HJSS Workshop/get_cosmos_data.py:27, in get_single_station_data(station_name, start_date, end_date, variable_list, site_info)
#      25 query_url = f'{BASE_URL}/collections/1D/locations/{station_name}?datetime={query_date_range}&parameter-name={",".join(variable_list)}'
#      26 resp = get_api_response(query_url)
# ---> 27 df = read_json_collection_data(resp)
#      28 df = df.reset_index()
#      29 return df
#
# File ~/Dev/Workshops/HJSS Workshop/get_cosmos_data.py:119, in read_json_collection_data(json_response)
#     112 # The response is a list of dictionaries, one for each requested site
#     113
#     114 # You can choose how you want to build your dataframes.  Here, I'm just loading all stations into one big dataframe.
#     115 # But you could modify this for your own use cases.  For example you might want to build a dictionary of {site_id: dataframe}
#     116 # to keep site data separate, etc.
#     117 master_df = pd.DataFrame()
# --> 119 for site_data in json_response["coverages"]:
#     120     # Read the site ID
#     121     site_id = site_data["dct:identifier"]
#     123     # Read the time stamps of each data point
#
# KeyError: 'coverages'

# %%
s_df['tdt1_vwc'].plot()
s_df['tdt1_vwc'].plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Tasks

# %% [markdown]
# ## Topic 2. Uncertainty in the rainfall record
# [Back to Index](#index)
#
# #### Contents
# - Load in rain gauge and grid data
# - Remove rain gauge data from dodgy gauges
# - Compare estimations of events, and the differences
#
# **Data sources:**
# - rain over Severn - object-store

# %% [markdown]
# ### 2.X removing incomplete gauges

# %% [markdown]
# # Topic 3. Determining floods and droughts
# [Back to Index](#index)
#
# #### Contents
# - Load in rain gauge
# - Download river flow data and catchment boundaries
#
# **Data sources:**
# - gridded rain over Severn - object-store
# - Severn sub-catchment boundaries and river flow - NRFA (manual download)
# - *maybe* Rivers - OpenRivers
